# %%
import sys
sys.path.append('/home/lpodgorsek/mag/scripts')

from relationGraph import Relation, RelationGraph, MatrixOfRelationGraph
from autoencoder import seedy, AutoEncoder
import utilityFunctions as uf
from main import test_build_relation_graph_with_symertic_data, test_convert_graph_to_2D_matrix, test_get_matix_for_autoencoder, test_autoencoder
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
from base import load_source
from base2 import load_dicty, load_pharma
import utilityFunctions as uf
import autoencoder as ae
import multimodal as mm


from os.path import join
import numpy as np
import multiprocessing

from scipy.spatial.distance import pdist, squareform
from fastcluster import linkage
import matplotlib.pyplot as plt

from tensorflow.keras.layers import Input, Dense, Embedding, Layer, Reshape, UpSampling2D, Flatten, Masking, Dropout, concatenate, Conv2D, MaxPooling2D, BatchNormalization, Lambda
from tensorflow.keras.models import Model, Sequential, load_model
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping
from tensorflow import set_random_seed
from tensorflow.keras.optimizers import SGD
from tensorflow.keras import backend as K
from sklearn.metrics import mean_squared_error

numOfExperiment = 17
path_data = '/home/lpodgorsek/data/cnn/dicty/'

# %load_ext autoreload
# %autoreload 2

# %%
graph1 = load_dicty('clustering', 2)
# graph2 = load_pharma()
# Out:
# 0.0
# 1.0
#
# 0.0
# 1.0
#
# 0.0
# 1.0
# -------------RelationGraph-------------
# Gene	1219
# 3	ann-(1024, 128), expr-(1024, 256), ppi-(1024, 1024)
# 0
# GO term	116
# 0
# 1	ann-(1024, 128)
# Experimental condition	282
# 0
# 1	expr-(1024, 256)

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

# display data
already_used = set()
list_data = []
for obj in graph1.objects.values():
    for relation in obj.relation_x:
        if relation.name not in already_used:
            list_data.append(relation.matrix)
            already_used.add(relation.name)
    
    for relation in obj.relation_y:
        if relation.name not in already_used:
            list_data.append(relation.matrix)
            already_used.add(relation.name)
        

color_pack = 'viridis'

for data in list_data:
#     fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(25, 6))
    plt.matshow(data, cmap=plt.cm.Blues)

    plt.show()

# %%
def sample_generator4(matrix, num_of_samples=1, density=0.8):
    # input  => sample_generator4([1219, 116], 1000, 0.8)
    # output => [1000, 1219, 116, 1]
    x_size, y_size = matrix.shape
    data = np.zeros((0, x_size, y_size, 1))
    print('Random seed: '  + str(np.random.randint(y_size)))
    
    while num_of_samples > 0:
        tmp_matrix = np.copy(matrix)
        for row in tmp_matrix:
            indices = np.random.choice(y_size, round(y_size * density), replace=False)
            mask = np.isin(np.arange(y_size), indices, invert=True)
            row[mask] = 0
            
        data = np.r_[data, tmp_matrix.reshape(1, x_size, y_size, 1)]                
        num_of_samples -= 1

    return data


def mp_worker(arr):
#     new_data = uf.sample_generator3(data, num_of_samples=100, density=0.7, 1)
    np.random.seed(arr[3])
    new_data = sample_generator4(arr[0], num_of_samples=arr[1], density=arr[2])
    return new_data


def data_generator_2(data, n_samples, pools, density, filename):
    batch_size = 1
    p = multiprocessing.Pool(pools)
    gen_samples = np.zeros((0, data.shape[0] * data.shape[1]))
    iterations = int(np.round((n_samples -1)/batch_size)) + 1
    
    params = [[data, batch_size, density, i] for i in range(iterations)]
    
    i = 1
    f = uf.my_savez(filename)
    for result in p.imap(mp_worker, params):
        print('samples: ' + str(i * batch_size))
        i+=1
        f.savez(result)
    f.close()


n_samples=10000
pools=6
density= .7

graph = graph1
# graph = graph2
for data in list_data:
    if data.shape[1] == 128:
        folder = '/data/samples/cnn/dicty/'
        data_generator_2(data, n_samples, pools, density, path_data + 'ann.npz')
    elif data.shape[1] == 256:
        folder = '/data/samples/cnn/dicty/'
        data_generator_2(data, n_samples, pools, density, path_data + 'expr.npz')
    elif data.shape[1] == 1024:
        folder = '/data/samples/cnn/dicty/'
        data_generator_2(data, n_samples, pools, density, path_data + 'ppi.npz')
# Out:
# Random seed: 172
# Random seed: 37
# Random seed: 168
# Random seed: 106
# Random seed: 122
# Random seed: 99
# Random seed: 138
# Random seed: 175
# Random seed: 195
# Random seed: 126
# Random seed: 9
# Random seed: 153
# Random seed: 75
# Random seed: 82
# Random seed: 107
# Random seed: 200
# samples: 1
# samples: 2
# samples: 3
# samples: 4
# samples: 5
# samples: 6
# samples: 7
# samples: 8
# samples: 9
# samples: 10
# Random seed: 169
# Random seed: 111
# Random seed: 42
# Random seed: 93
# Random seed: 99
# Random seed: 201
# Random seed: 117
# Random seed: 83
# Random seed: 162
# Random seed: 132
# Random seed: 53
# Random seed: 19
# samples: 11
# samples: 12
# samples: 13
# samples: 14
# samples: 15
# samples: 16
# samples: 17
# samples: 18
# samples: 19
# samples: 20
# Random seed: 1
# Random seed: 213
# Random seed: 37
# Random seed: 210
# Random seed: 215
# Random seed: 20
# Random seed: 161
# Random seed: 201
# Random seed: 133
# samples: 21
# samples: 22
# samples: 23
# samples: 24
# samples: 25
# samples: 26
# samples: 27
# samples: 28
# samples: 29
# samples: 30
# samples: 31
# Random seed: 143
# Random seed: 161
# Random seed: 137
# Random seed: 70
# Random seed: 192
# Random seed: 102
# Random seed: 68
# Random seed: 20
# Random seed: 203
# Random seed: 189
# samples: 32
# samples: 33
# samples: 34
# samples: 35
# samples: 36
# samples: 37
# samples: 38
# samples: 39
# samples: 40
# samples: 41
# Random seed: 135
# Random seed: 0
# Random seed: 170
# Random seed: 176
# Random seed: 254
# Random seed: 245
# Random seed: 25
# Random seed: 111
# Random seed: 205
# Random seed: 85
# Random seed: 207
# Random seed: 35
# samples: 42
# samples: 43
# samples: 44
# samples: 45
# samples: 46
# samples: 47
# samples: 48
# samples: 49
# samples: 50
# samples: 51
# samples: 52
# samples: 53
# Random seed: 177
# Random seed: 205
# Random seed: 99
# Random seed: 18
# Random seed: 44
# Random seed: 196
# Random seed: 46
# Random seed: 20
# Random seed: 67
# Random seed: 63
# Random seed: 54
# Random seed: 78
# samples: 54
# samples: 55
# samples: 56
# samples: 57
# samples: 58
# samples: 59
# samples: 60
# samples: 61
# samples: 62
# samples: 63
# samples: 64
# samples: 65
# Random seed: 107
# Random seed: 216
# Random seed: 150
# Random seed: 158
# Random seed: 248
# Random seed: 161
# Random seed: 215
# Random seed: 197
# Random seed: 87
# Random seed: 175
# Random seed: 67
# Random seed: 131
# samples: 66
# samples: 67
# samples: 68
# samples: 69
# samples: 70
# samples: 71
# samples: 72
# samples: 73
# Random seed: 82
# Random seed: 170
# Random seed: 106
# Random seed: 148
# Random seed: 230
# Random seed: 216
# Random seed: 147
# Random seed: 91
# Random seed: 178
# samples: 74
# samples: 75
# samples: 76
# samples: 77
# Random seed: 247
# Random seed: 47
# Random seed: 79
# Random seed: 106
# Random seed: 74
# Random seed: 167
# Random seed: 48
# Random seed: 153
# samples: 1042
# samples: 1043
# samples: 1044
# samples: 1045
# samples: 1046
# samples: 1047
# samples: 1048
# samples: 1049
# samples: 1050
# samples: 1051
# samples: 1052
# samples: 1053
# Random seed: 216
# Random seed: 116
# Random seed: 75
# Random seed: 27
# Random seed: 141
# Random seed: 28
# Random seed: 66
# Random seed: 103
# Random seed: 25
# Random seed: 2
# Random seed: 228
# Random seed: 149
# Random seed: 59
# samples: 1054
# samples: 1055
# samples: 1056
# samples: 1057
# samples: 1058
# samples: 1059
# samples: 1060
# samples: 1061
# samples: 1062
# samples: 1063
# samples: 1064
# samples: 1065
# samples: 1066
# Random seed: 252
# Random seed: 122
# Random seed: 203
# Random seed: 32
# Random seed: 18
# Random seed: 166
# Random seed: 135
# Random seed: 195
# Random seed: 69
# Random seed: 160
# Random seed: 177
# samples: 1067
# samples: 1068
# samples: 1069
# samples: 1070
# samples: 1071
# samples: 1072
# samples: 1073
# samples: 1074
# samples: 1075
# samples: 1076
# samples: 1077
# Random seed: 103
# Random seed: 248
# Random seed: 230
# Random seed: 165
# Random seed: 27
# Random seed: 217
# Random seed: 211
# Random seed: 38
# Random seed: 197
# Random seed: 216
# Random seed: 38
# samples: 1078
# samples: 1079
# samples: 1080
# samples: 1081
# samples: 1082
# samples: 1083
# samples: 1084
# samples: 1085
# samples: 1086
# samples: 1087
# samples: 1088
# Random seed: 64
# Random seed: 33
# Random seed: 64
# Random seed: 221
# Random seed: 180
# Random seed: 12
# Random seed: 134
# Random seed: 94
# Random seed: 45
# Random seed: 21
# Random seed: 33
# samples: 1089
# samples: 1090
# samples: 1091
# samples: 1092
# samples: 1093
# samples: 1094
# samples: 1095
# samples: 1096
# samples: 1097
# samples: 1098
# samples: 1099
# Random seed: 64
# Random seed: 61
# Random seed: 144
# Random seed: 154
# Random seed: 95
# Random seed: 179
# Random seed: 156
# Random seed: 4
# Random seed: 46
# samples: 1100
# samples: 1101
# samples: 1102
# samples: 1103
# samples: 1104
# samples: 1105
# samples: 1106
# samples: 1107
# samples: 1108
# Random seed: 185
# Random seed: 248
# Random seed: 228
# Random seed: 147
# Random seed: 61
# Random seed: 124
# Random seed: 99
# Random seed: 246
# Random seed: 133
# Random seed: 72
# Random seed: 216
# Random seed: 254
# samples: 1109
# samples: 1110
# samples: 1111
# samples: 1112
# samples: 1113
# samples: 1114
# samples: 1115
# samples: 1116
# samples: 1117
# samples: 1118
# samples: 1119
# samples: 1120
# Random seed: 96
# Random seed: 87
# Random seed: 232
# Random seed: 154
# Random seed: 103
# Random seed: 41
# Random seed: 33
# Random seed: 92
# Random seed: 252
# Random seed: 60
# Random seed: 141
# samples: 1121
# samples: 1122
# samples: 1123
# samples: 1124
# samples: 1125
# samples: 1126
# samples: 1127
# samples: 1128
# samples: 1129
# samples: 1130
# samples: 1131
# Random seed: 8
# Random seed: 182
# Random seed: 15
# Random seed: 148
# Random seed: 164
# Random seed: 16
# Random seed: 47
# Random seed: 203
# Random seed: 35
# Random seed: 11
# samples: 1222
# samples: 1223
# samples: 1224
# samples: 1225
# samples: 1226
# samples: 1227
# samples: 1228
# samples: 1229
# samples: 1230
# samples: 1231
# samples: 1232
# Random seed: 196
# Random seed: 243
# Random seed: 175
# Random seed: 57
# Random seed: 79
# Random seed: 179
# Random seed: 172
# Random seed: 251
# Random seed: 98
# Random seed: 50
# Random seed: 74
# Random seed: 139
# samples: 1233
# samples: 1234
# samples: 1235
# samples: 1236
# samples: 1237
# samples: 1238
# samples: 1239
# samples: 1240
# samples: 1241
# samples: 1242
# samples: 1243
# Random seed: 53
# Random seed: 116
# Random seed: 202
# Random seed: 6
# Random seed: 16
# Random seed: 12
# Random seed: 193
# Random seed: 148
# Random seed: 161
# Random seed: 204
# samples: 1244
# samples: 1245
# samples: 1246
# samples: 1247
# samples: 1248
# samples: 1249
# samples: 1250
# samples: 1251
# samples: 1252
# samples: 1253
# samples: 1254
# Random seed: 252
# Random seed: 58
# Random seed: 222
# Random seed: 239
# Random seed: 250
# Random seed: 195
# Random seed: 85
# Random seed: 55
# Random seed: 62
# Random seed: 219
# Random seed: 46
# Random seed: 56
# samples: 1255
# samples: 1256
# samples: 1257
# samples: 1258
# samples: 1259
# samples: 1260
# samples: 1261
# samples: 1262
# samples: 1263
# samples: 1264
# samples: 1265
# samples: 1266
# Random seed: 3
# Random seed: 111
# Random seed: 137
# Random seed: 140
# Random seed: 133
# Random seed: 254
# Random seed: 133
# Random seed: 215
# Random seed: 189
# Random seed: 247
# Random seed: 169
# samples: 1267
# samples: 1268
# samples: 1269
# samples: 1270
# samples: 1271
# samples: 1272
# samples: 1273
# samples: 1274
# samples: 1275
# samples: 1276
# samples: 1277
# Random seed: 253
# Random seed: 166
# Random seed: 238
# Random seed: 180
# Random seed: 27
# Random seed: 201
# Random seed: 172
# Random seed: 221
# samples: 1278
# samples: 1279
# samples: 1280
# samples: 1281
# samples: 1282
# samples: 1283
# samples: 1284
# samples: 1285
# Random seed: 50
# Random seed: 160
# Random seed: 225
# Random seed: 165
# Random seed: 182
# Random seed: 66
# Random seed: 234
# Random seed: 123
# Random seed: 118
# Random seed: 186
# Random seed: 171
# samples: 1286
# samples: 1287
# samples: 1288
# samples: 1289
# samples: 1290
# samples: 1291
# samples: 1292
# samples: 1293
# samples: 1294
# samples: 1295
# samples: 1296
# Random seed: 49
# Random seed: 45
# Random seed: 63
# Random seed: 78
# Random seed: 203
# Random seed: 122
# Random seed: 37
# Random seed: 48
# Random seed: 52
# Random seed: 57
# samples: 1297
# samples: 1298
# samples: 1299
# samples: 1300
# samples: 1301
# samples: 1302
# samples: 1303
# samples: 1304
# samples: 1305
# samples: 1306
# Random seed: 82
# Random seed: 112
# Random seed: 69
# Random seed: 246
# Random seed: 14
# Random seed: 68
# Random seed: 119
# Random seed: 238
# Random seed: 172
# Random seed: 194
# samples: 1307
# samples: 1308
# samples: 1309
# samples: 1310
# samples: 1311
# samples: 1312
# samples: 1313
# samples: 1314
# samples: 1315
# samples: 1316
# Random seed: 231
# Random seed: 79
# Random seed: 34
# Random seed: 233
# Random seed: 252
# Random seed: 96
# Random seed: 56
# Random seed: 144
# Random seed: 43
# Random seed: 191
# Random seed: 200
# samples: 1317
# samples: 1318
# samples: 1319
# samples: 1320
# samples: 1321
# samples: 1322
# samples: 1323
# samples: 1324
# samples: 1325
# samples: 1326
# samples: 1327
# Random seed: 121
# Random seed: 83
# Random seed: 62
# Random seed: 164
# Random seed: 151
# Random seed: 176
# Random seed: 201
# Random seed: 83
# samples: 1328
# samples: 1329
# samples: 1330
# samples: 1331
# samples: 1332
# samples: 1333
# samples: 1334
# samples: 1335
# Random seed: 170
# Random seed: 2
# Random seed: 141
# Random seed: 193
# Random seed: 130
# Random seed: 39
# Random seed: 216
# Random seed: 138
# Random seed: 18
# Random seed: 235
# Random seed: 131
# samples: 1336
# samples: 1337
# samples: 1338
# samples: 1339
# samples: 1340
# samples: 1341
# samples: 1342
# samples: 1343
# samples: 1344
# samples: 1345
# samples: 1346
# Random seed: 50
# Random seed: 226
# Random seed: 244
# Random seed: 13
# Random seed: 58
# Random seed: 51
# Random seed: 118
# Random seed: 148
# Random seed: 58
# Random seed: 185
# Random seed: 61
# Random seed: 79
# samples: 1347
# samples: 1348
# samples: 1349
# samples: 1350
# samples: 1351
# samples: 1352
# samples: 1353
# samples: 1354
# samples: 1355
# samples: 1356
# samples: 1357
# samples: 1358
# Random seed: 37
# Random seed: 82
# Random seed: 169
# Random seed: 154
# Random seed: 191
# Random seed: 199
# Random seed: 205
# Random seed: 65
# Random seed: 212
# Random seed: 5
# Random seed: 37
# samples: 1359
# samples: 1360
# samples: 1361
# samples: 1362
# samples: 1363
# samples: 1364
# samples: 1365
# samples: 1366
# samples: 1367
# samples: 1368
# samples: 1369
# Random seed: 191
# Random seed: 94
# Random seed: 54
# Random seed: 233
# Random seed: 173
# Random seed: 198
# Random seed: 140
# Random seed: 220
# Random seed: 161
# Random seed: 11
# Random seed: 240
# Random seed: 41
# samples: 1370
# samples: 1371
# samples: 1372
# samples: 1373
# samples: 1374
# samples: 1375
# samples: 1376
# samples: 1377
# samples: 1378
# samples: 1379
# samples: 1380
# Random seed: 95
# Random seed: 138
# Random seed: 255
# Random seed: 48
# Random seed: 25
# Random seed: 80
# Random seed: 243
# samples: 1381
# samples: 1382
# samples: 1383
# samples: 1384
# samples: 1385
# samples: 1386
# samples: 1387
# samples: 1388
# samples: 1389
# Random seed: 126
# Random seed: 183
# Random seed: 161
# Random seed: 202
# Random seed: 234
# Random seed: 247
# Random seed: 75
# Random seed: 66
# Random seed: 57
# Random seed: 92
# Random seed: 133
# Random seed: 55
# samples: 1390
# samples: 1391
# samples: 1392
# samples: 1393
# samples: 1394
# samples: 1395
# samples: 1396
# samples: 1397
# samples: 1398
# samples: 1399
# samples: 1400
# Random seed: 77
# Random seed: 218
# Random seed: 165
# Random seed: 29
# Random seed: 115
# Random seed: 78
# Random seed: 6
# Random seed: 104
# Random seed: 108
# Random seed: 134
# Random seed: 188
# Random seed: 228
# samples: 1401
# samples: 1402
# samples: 1403
# samples: 1404
# samples: 1405
# samples: 1406
# samples: 1407
# samples: 1408
# samples: 1409
# samples: 1410
# samples: 1411
# Random seed: 43
# Random seed: 69
# Random seed: 199
# Random seed: 245
# Random seed: 104
# Random seed: 108
# Random seed: 185
# Random seed: 62
# Random seed: 182
# samples: 1412
# samples: 1413
# samples: 1414
# samples: 1415
# samples: 1416
# samples: 1417
# samples: 1418
# samples: 1419
# samples: 1420
# samples: 1421
# Random seed: 72
# Random seed: 116
# Random seed: 255
# Random seed: 4
# Random seed: 172
# Random seed: 200
# Random seed: 229
# Random seed: 124
# Random seed: 118
# Random seed: 180
# samples: 1422
# samples: 1423
# samples: 1424
# samples: 1425
# samples: 1426
# samples: 1427
# samples: 1428
# samples: 1429
# samples: 1430
# samples: 1431
# Random seed: 174
# Random seed: 57
# Random seed: 227
# Random seed: 135
# Random seed: 153
# Random seed: 25
# Random seed: 174
# Random seed: 71
# Random seed: 60
# samples: 1432
# samples: 1433
# samples: 1434
# Random seed: 141
# Random seed: 70
# Random seed: 210
# Random seed: 147
# Random seed: 35
# Random seed: 25
# Random seed: 99
# Random seed: 13
# Random seed: 67
# Random seed: 211
# Random seed: 104
# Random seed: 238
# Random seed: 141
# Random seed: 80
# Random seed: 44
# Random seed: 144
# Random seed: 238
# Random seed: 182
# Random seed: 237
# Random seed: 110
# Random seed: 82
# Random seed: 211
# Random seed: 157
# Random seed: 154
# Random seed: 198
# Random seed: 36
# Random seed: 224
# Random seed: 142
# Random seed: 86
# Random seed: 17
# Random seed: 244
# Random seed: 168
# Random seed: 203
# Random seed: 220
# Random seed: 176
# Random seed: 71
# Random seed: 95
# Random seed: 132
# Random seed: 105
# Random seed: 251
# Random seed: 243
# Random seed: 242
# Random seed: 215
# Random seed: 123
# Random seed: 233
# Random seed: 148
# Random seed: 215
# Random seed: 203
# Random seed: 13
# Random seed: 16
# Random seed: 74
# Random seed: 56
# Random seed: 128
# Random seed: 209
# Random seed: 19
# Random seed: 147
# Random seed: 210
# Random seed: 56
# Random seed: 5
# Random seed: 43
# Random seed: 176
# Random seed: 185
# Random seed: 181
# Random seed: 68
# Random seed: 210
# Random seed: 203
# Random seed: 81
# Random seed: 16
# Random seed: 78
# Random seed: 199
# Random seed: 20
# Random seed: 6
# Random seed: 199
# Random seed: 13
# Random seed: 188
# Random seed: 72
# Random seed: 202
# Random seed: 113
# Random seed: 154
# Random seed: 231
# Random seed: 199
# Random seed: 221
# Random seed: 59
# Random seed: 253
# Random seed: 167
# Random seed: 28
# Random seed: 128
# Random seed: 69
# Random seed: 208
# Random seed: 213
# Random seed: 205
# Random seed: 185
# Random seed: 180
# Random seed: 7
# Random seed: 242
# Random seed: 127
# Random seed: 172
# Random seed: 181
# Random seed: 184
# Random seed: 12
# Random seed: 98
# Random seed: 175
# samples: 1435
# samples: 1436
# samples: 1437
# samples: 1438
# samples: 1439
# samples: 1440
# samples: 1441
# samples: 1442
# samples: 1443
# samples: 1444
# samples: 1445
# samples: 9916
# samples: 9917
# samples: 9918
# samples: 9919
# samples: 9920
# Random seed: 101
# Random seed: 235
# Random seed: 672
# Random seed: 110
# Random seed: 107
# Random seed: 587
# samples: 9921
# samples: 9922
# samples: 9923
# samples: 9924
# samples: 9925
# samples: 9926
# Random seed: 426
# Random seed: 936
# Random seed: 112
# Random seed: 79
# Random seed: 870
# Random seed: 689
# samples: 9927
# samples: 9928
# samples: 9929
# samples: 9930
# samples: 9931
# Random seed: 1021
# Random seed: 688
# Random seed: 729
# Random seed: 616
# Random seed: 106
# samples: 9932
# samples: 9933
# samples: 9934
# samples: 9935
# samples: 9936
# Random seed: 838
# Random seed: 580
# Random seed: 182
# Random seed: 902
# samples: 9937
# samples: 9938
# samples: 9939
# samples: 9940
# samples: 9941
# Random seed: 174
# Random seed: 189
# Random seed: 323
# Random seed: 371
# Random seed: 156
# samples: 9942
# samples: 9943
# samples: 9944
# samples: 9945
# samples: 9946
# Random seed: 508
# Random seed: 716
# Random seed: 541
# Random seed: 95
# Random seed: 580
# Random seed: 701
# samples: 9947
# samples: 9948
# samples: 9949
# samples: 9950
# samples: 9951
# samples: 9952
# Random seed: 311
# Random seed: 59
# Random seed: 605
# Random seed: 969
# samples: 9953
# samples: 9954
# samples: 9955
# samples: 9956
# Random seed: 312
# Random seed: 519
# Random seed: 762
# Random seed: 962
# Random seed: 131
# Random seed: 924
# samples: 9957
# Random seed: 463
# Random seed: 1003
# Random seed: 616
# Random seed: 589
# Random seed: 752
# Random seed: 352
# Random seed: 445
# Random seed: 370
# Random seed: 280
# Random seed: 613
# Random seed: 442
# Random seed: 576
# Random seed: 242
# Random seed: 252
# Random seed: 733
# Random seed: 580
# Random seed: 751
# Random seed: 215
# Random seed: 692
# Random seed: 536
# Random seed: 35
# Random seed: 421
# Random seed: 619
# Random seed: 705
# Random seed: 669
# Random seed: 243
# samples: 9958
# samples: 9959
# samples: 9960
# samples: 9961
# samples: 9962
# samples: 9963
# samples: 9964
# samples: 9965
# samples: 9966
# Random seed: 578
# Random seed: 227
# Random seed: 658
# Random seed: 259
# samples: 9967
# samples: 9968
# samples: 9969
# samples: 9970
# samples: 9971
# samples: 9972
# samples: 9973
# samples: 9974
# samples: 9975
# samples: 9976
# Random seed: 217
# Random seed: 86
# samples: 9977
# samples: 9978
# samples: 9979
# samples: 9980
# samples: 9981
# samples: 9982
# samples: 9983
# samples: 9984
# samples: 9985
# samples: 9986
# samples: 9987
# samples: 9988
# samples: 9989
# samples: 9990
# samples: 9991
# samples: 9992
# samples: 9993
# samples: 9994
# samples: 9995
# samples: 9996
# samples: 9997
# samples: 9998
# samples: 9999
# samples: 10000

# %%
def data_generator(filenames, org_data, batch_size=1):
    # n_pack => 100 samples of matrix
    # n_pack = batch_size
    files = []              # different files
    num_packs = []          # subpacked inside of file
    for filename in filenames:
        f = np.load(filename)
        files.append(f)
        num_packs.append(f.files)
    
    counter = 0
    while True:
        x = []
        y = []
        for i in range(len(files)):
            for j in range(batch_size):
                rand_num = np.random.randint(len(num_packs[i]))
                f = files[i]
                pack = num_packs[i]
                data = f[pack[rand_num]] 
    #             new_data = top_N_rows(data)
    #             x.append(new_data)

                x.append(f[pack[rand_num]])
                y.append(org_data)
            
        x = np.asarray(x)
        y = np.asarray(y)
        
        x = x[:, 0, :, :, :]
        y = y[:, 0, :, :, :]
        
        yield ([x], [y])
        
        if counter >= batch_size:
            counter = 0

d = []

for data in list_data:
    if data.shape[1] == 128:
        d = data
        
row, col = d.shape
input_img = Input(shape=(row, col, 1))  # adapt this if using `channels_first` image data format
x = Conv2D(128, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2, 2), padding='same')(x)

ae = Flatten()(encoded)
ae = Dense(1024, activation='relu')(ae)
ae = Dense(512, activation='relu')(ae)
ae = Dense(256, activation='relu')(ae)
ae = Dense(128, activation='relu')(ae)
ae = Dense(64, activation='relu')(ae)
ae = Dense(128, activation='relu')(ae)
ae = Dense(256, activation='relu')(ae)
ae = Dense(512, activation='relu')(ae)
# ae = Dense(1024, activation='relu')(ae)
ae = Reshape((64, 8, 1))(ae)


# at this point the representation is (4, 4, 8) i.e. 128-dimensional

x = Conv2D(16, (3, 3), activation='relu', padding='same')(ae)
x = UpSampling2D((2, 2))(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = Model(input_img, decoded)
sgd = SGD(lr=0.001, decay=1e-6)
# autoencoder.compile(optimizer=sgd, loss='mse')
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')
autoencoder.summary() 
folder = '/data/samples/cnn/dicty/'
autoencoder.fit_generator(
    data_generator([folder+'ann.npz'], d.reshape(1, row, col, 1), 16), 
    steps_per_epoch=100, 
    epochs=100
)

autoencoder.save('/data/multimodal/dicty/experiment_' + str(numOfExperiment) +'_cnn_ann.h5')

predict = autoencoder.predict(d.reshape(1, row, col, 1))
print(predict.shape)
print(data.shape)
mse = mean_squared_error(d, predict.reshape(row, col))
print('MSE: ' + str(mse))

import matplotlib.pyplot as plt
import matplotlib as mpl

path = '/mag/Experiments/Results/'+ str(numOfExperiment) + '/dicty/'

# color_pack = 'Blues'
# color_pack = 'jet'
color_pack = 'viridis'
color_pack2 = 'RdBu'
# color_pack = 'binary'
# color_pack = 'PuOr'
# color_pack = 'rainbow'

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(25, 6))
org_data = d
predict = predict.reshape((row, col))

print(np.min(predict))
print(np.max(predict))


ax = axes[0]
im = ax.imshow(org_data, vmin=0, vmax=1, cmap=plt.cm.get_cmap(color_pack))

ax = axes[1]
im2 = ax.imshow(predict, vmin=np.min(predict), vmax=np.max(predict), cmap=plt.cm.get_cmap(color_pack2))

#     ax = axes[2]
#     im = ax.imshow(predict - org_data, vmin=-1, vmax=1, cmap=plt.cm.get_cmap(color_pack))
     
# fig.colorbar(im, ax=axes.ravel().tolist())
#     cax,kw = mpl.colorbar.make_axes([ax for ax in axes.flat])
cax,kw = mpl.colorbar.make_axes([axes[0]])
cax2,kw2 = mpl.colorbar.make_axes([axes[1]])
cba = plt.colorbar(im, cax=cax, **kw)
cbb = plt.colorbar(im2, cax=cax2, **kw2)

plt.savefig(path + 'experiment' + str(numOfExperiment) + '_ann_org_vs_predict.png')

plt.show()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 1024, 128, 1)      0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 1024, 128, 128)    1280
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 512, 64, 128)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 512, 64, 64)       73792
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 256, 32, 64)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 256, 32, 32)       18464
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 128, 16, 32)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 128, 16, 16)       4624
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 64, 8, 16)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              8389632
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               131584
# _________________________________________________________________
# reshape (Reshape)            (None, 64, 8, 1)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 64, 8, 16)         160
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 128, 16, 16)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 128, 16, 32)       4640
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 256, 32, 32)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 256, 32, 64)       18496
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 512, 64, 64)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 512, 64, 128)      73856
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 1024, 128, 128)    0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 1024, 128, 1)      1153
# =================================================================
# Total params: 9,456,305
# Trainable params: 9,456,305
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
#  19/100 [====>.........................] - ETA: 1:02 - loss: 0.3730

# %%
for data in list_data:
    if data.shape[1] == 128:
        d = data

row, col = d.shape
        
autoencoder = load_model('/data/multimodal/dicty/experiment_' + str(numOfExperiment) +'_cnn_ann.h5')

predict = autoencoder.predict(d.reshape(1, row, col, 1))
print(predict.shape)
print(data.shape)
mse = mean_squared_error(d, predict.reshape(row, col))
print('MSE: ' + str(mse))

import matplotlib.pyplot as plt
import matplotlib as mpl

path = '/mag/Experiments/Results/'+ str(numOfExperiment) + '/dicty/'

# color_pack = 'Blues'
# color_pack = 'jet'
color_pack = 'viridis'
color_pack2 = 'RdBu'
# color_pack = 'binary'
# color_pack = 'PuOr'
# color_pack = 'rainbow'

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(25, 6))
org_data = d
predict = predict.reshape((row, col))

print(np.min(predict))
print(np.max(predict))


ax = axes[0]
im = ax.imshow(org_data, vmin=0, vmax=1, cmap=plt.cm.get_cmap(color_pack))

ax = axes[1]
im2 = ax.imshow(predict, vmin=np.min(predict), vmax=np.max(predict), cmap=plt.cm.get_cmap(color_pack2))

#     ax = axes[2]
#     im = ax.imshow(predict - org_data, vmin=-1, vmax=1, cmap=plt.cm.get_cmap(color_pack))
     
# fig.colorbar(im, ax=axes.ravel().tolist())
#     cax,kw = mpl.colorbar.make_axes([ax for ax in axes.flat])
cax,kw = mpl.colorbar.make_axes([axes[0]])
cax2,kw2 = mpl.colorbar.make_axes([axes[1]])
cba = plt.colorbar(im, cax=cax, **kw)
cbb = plt.colorbar(im2, cax=cax2, **kw2)

plt.savefig(path + 'experiment' + str(numOfExperiment) + '_ann_org_vs_predict.png')

plt.show()
# Out:
# (1, 1024, 128, 1)
# (1024, 1024)
# MSE: 0.00416115252299418
# 0.0
# 1.0

# %%
def shuffle_data(org_data):
    row, col = org_data.shape
    tmp_data = org_data.flatten()
    np.random.shuffle(tmp_data)  # shuffle org data
    return np.array(tmp_data).reshape(row, col)

    
shuffled_data = shuffle_data(org_data)
shuffled_predict = autoencoder.predict(d.reshape(1, row, col, 1))

outputHeader = 'Data\t\t'
outputHeader += 'Density\t\t'
outputHeader += 'Predict\t\t'
outputHeader += 'BaseLine\t'
outputHeader += 'AVG Mean\t'
outputHeader += 'Predict (mean)\t'
# outputHeader += 'Predict (min)\t'
# outputHeader += 'Predict (max)\t'
print(outputHeader)

#         print('Data \t\t\tDensity \tPredict \tBaseLine \tAVG Mean')
row, col = org_data.shape 
mse = mean_squared_error(org_data.flatten(), predict.flatten())
mse_base_line = mean_squared_error(shuffled_data.flatten(), shuffled_predict.flatten())

non_zeros = org_data.flatten()
non_zeros[org_data.flatten() > 0] = 1
org_mean = round(np.mean(non_zeros * org_data.flatten()), 5)
predict_mean = round(np.mean(non_zeros * predict.flatten()), 5)

outputBody = '(' + str(row) + ',' + str(col) + ') ' + '\t'
outputBody += str(round((np.count_nonzero(org_data)/(row * col)) * 100, 2)) + '% \t\t'
outputBody += str(round(mse * 100, 5)) + '% \t'
outputBody += str(round(mse_base_line * 100, 5)) + '% '+ '\t'
outputBody += str(org_mean) + '\t\t'
outputBody += str(predict_mean) + '\t\t'
# outputBody += str(round(min(predict.flatten()), 5)) + '\t\t'
# outputBody += str(round(max(predict.flatten()), 5)) + '\t'
print(outputBody)
# Out:
# (131072,)
# (131072,)
# (131072,)
# Data		Density		Predict		BaseLine	AVG Mean	Predict (mean)
# (1024,128) 	4.89% 		0.41612% 	8.90193% 	0.04888		0.04477

# %%
def data_generator(filenames, org_data, batch_size=1):
    # n_pack => 100 samples of matrix
    # n_pack = batch_size
    files = []              # different files
    num_packs = []          # subpacked inside of file
    for filename in filenames:
        f = np.load(filename)
        files.append(f)
        num_packs.append(f.files)
    
    counter = 0
    while True:
        x = []
        y = []
        for i in range(len(files)):
            for j in range(batch_size):
                rand_num = np.random.randint(len(num_packs[i]))
                f = files[i]
                pack = num_packs[i]
                data = f[pack[rand_num]] 
    #             new_data = top_N_rows(data)
    #             x.append(new_data)

                x.append(f[pack[rand_num]])
                y.append(org_data)
            
        x = np.asarray(x)
        y = np.asarray(y)
        
        x = x[:, 0, :, :, :]
        y = y[:, 0, :, :, :]
        
        yield ([x], [y])
        
        if counter >= batch_size:
            counter = 0

d = []
file = 'expr'

for data in list_data:
    if data.shape[1] == 256:
        d = data
        
row, col = d.shape
input_img = Input(shape=(row, col, 1))  # adapt this if using `channels_first` image data format
x = Conv2D(128, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2, 2), padding='same')(x)

ae = Flatten()(encoded)
ae = Dense(1024, activation='relu')(ae)
ae = Dense(512, activation='relu')(ae)
ae = Dense(256, activation='relu')(ae)
ae = Dense(128, activation='relu')(ae)
ae = Dense(64, activation='relu')(ae)
ae = Dense(128, activation='relu')(ae)
ae = Dense(256, activation='relu')(ae)
ae = Dense(512, activation='relu')(ae)
ae = Dense(1024, activation='relu')(ae)
ae = Reshape((64, 16, 1))(ae)


# at this point the representation is (4, 4, 8) i.e. 128-dimensional

x = Conv2D(16, (3, 3), activation='relu', padding='same')(ae)
x = UpSampling2D((2, 2))(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = Model(input_img, decoded)
sgd = SGD(lr=0.001, decay=1e-6)
# autoencoder.compile(optimizer=sgd, loss='mse')
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')
autoencoder.summary() 
folder = '/data/samples/cnn/dicty/'
autoencoder.fit_generator(
    data_generator([folder+file+'.npz'], d.reshape(1, row, col, 1), 16), 
    steps_per_epoch=100, 
    epochs=100
)

autoencoder.save('/data/multimodal/dicty/experiment_'+ str(numOfExperiment) + '_cnn_' + file +'.h5')

predict = autoencoder.predict(d.reshape(1, row, col, 1))
print(predict.shape)
print(data.shape)
mse = mean_squared_error(d, predict.reshape(row, col))
print('MSE: ' + str(mse))

import matplotlib.pyplot as plt
import matplotlib as mpl

path = '/mag/Experiments/Results/'+ str(numOfExperiment) + '/dicty/'

# color_pack = 'Blues'
# color_pack = 'jet'
color_pack = 'viridis'
color_pack2 = 'RdBu'
# color_pack = 'binary'
# color_pack = 'PuOr'
# color_pack = 'rainbow'

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(25, 6))
org_data = d
predict = predict.reshape((row, col))

print(np.min(predict))
print(np.max(predict))


ax = axes[0]
im = ax.imshow(org_data, vmin=0, vmax=1, cmap=plt.cm.get_cmap(color_pack))

ax = axes[1]
im2 = ax.imshow(predict, vmin=np.min(predict), vmax=np.max(predict), cmap=plt.cm.get_cmap(color_pack2))

#     ax = axes[2]
#     im = ax.imshow(predict - org_data, vmin=-1, vmax=1, cmap=plt.cm.get_cmap(color_pack))

# fig.colorbar(im, ax=axes.ravel().tolist())
#     cax,kw = mpl.colorbar.make_axes([ax for ax in axes.flat])
cax,kw = mpl.colorbar.make_axes([axes[0]])
cax2,kw2 = mpl.colorbar.make_axes([axes[1]])
cba = plt.colorbar(im, cax=cax, **kw)
cbb = plt.colorbar(im2, cax=cax2, **kw2)

plt.savefig(path + 'experiment' + str(numOfExperiment) + '_' + file + '_org_vs_predict.png')

plt.show()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 1024, 256, 1)      0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 1024, 256, 128)    1280
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 512, 128, 128)     0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 512, 128, 64)      73792
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 256, 64, 64)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 256, 64, 32)       18464
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 128, 32, 32)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 128, 32, 16)       4624
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 64, 16, 16)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 16384)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              16778240
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               131584
# _________________________________________________________________
# dense_8 (Dense)              (None, 1024)              525312
# _________________________________________________________________
# reshape (Reshape)            (None, 64, 16, 1)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 64, 16, 16)        160
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 128, 32, 16)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 128, 32, 32)       4640
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 256, 64, 32)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 256, 64, 64)       18496
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 512, 128, 64)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 512, 128, 128)     73856
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 1024, 256, 128)    0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 1024, 256, 1)      1153
# =================================================================
# Total params: 18,370,225
# Trainable params: 18,370,225
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 100/100 [==============================] - 85s 852ms/step - loss: 0.4709
# Epoch 2/100
# 100/100 [==============================] - 77s 768ms/step - loss: 0.4063
# Epoch 3/100
# 100/100 [==============================] - 77s 766ms/step - loss: 0.4023
# Epoch 4/100
# 100/100 [==============================] - 77s 766ms/step - loss: 0.4013
# Epoch 5/100
# 100/100 [==============================] - 77s 766ms/step - loss: 0.4004
# Epoch 6/100
# 100/100 [==============================] - 77s 767ms/step - loss: 0.3998
# Epoch 7/100
# 100/100 [==============================] - 77s 770ms/step - loss: 0.3994
# Epoch 8/100
# 100/100 [==============================] - 77s 768ms/step - loss: 0.3990
# Epoch 9/100
# 100/100 [==============================] - 77s 767ms/step - loss: 0.3987
# Epoch 10/100
# 100/100 [==============================] - 77s 768ms/step - loss: 0.3984
# Epoch 11/100
# 100/100 [==============================] - 77s 766ms/step - loss: 0.3981
# Epoch 12/100
# 100/100 [==============================] - 77s 770ms/step - loss: 0.3979
# Epoch 13/100
# 100/100 [==============================] - 77s 766ms/step - loss: 0.3976
# Epoch 14/100
# 100/100 [==============================] - 77s 768ms/step - loss: 0.3955
# Epoch 15/100
# 100/100 [==============================] - 77s 768ms/step - loss: 0.3952
# Epoch 16/100
# 100/100 [==============================] - 77s 767ms/step - loss: 0.3949
# Epoch 17/100
# 100/100 [==============================] - 77s 768ms/step - loss: 0.3947
# Epoch 18/100
# 100/100 [==============================] - 77s 766ms/step - loss: 0.3945
# Epoch 19/100
# 100/100 [==============================] - 77s 768ms/step - loss: 0.3943
# Epoch 20/100
# 100/100 [==============================] - 77s 765ms/step - loss: 0.3942
# Epoch 21/100
# 100/100 [==============================] - 77s 768ms/step - loss: 0.3940
# Epoch 22/100
# 100/100 [==============================] - 77s 769ms/step - loss: 0.3939
# Epoch 23/100
# 100/100 [==============================] - 76s 764ms/step - loss: 0.3938
# Epoch 24/100
# 100/100 [==============================] - 77s 767ms/step - loss: 0.3937
# Epoch 25/100
# 100/100 [==============================] - 77s 768ms/step - loss: 0.3935
# Epoch 26/100
# 100/100 [==============================] - 77s 770ms/step - loss: 0.3934
# Epoch 27/100
# 100/100 [==============================] - 77s 768ms/step - loss: 0.3936
# Epoch 28/100
# 100/100 [==============================] - 77s 767ms/step - loss: 0.3928
# Epoch 29/100
# 100/100 [==============================] - 77s 766ms/step - loss: 0.3928
# Epoch 30/100
# 100/100 [==============================] - 77s 767ms/step - loss: 0.3927
# Epoch 31/100
# 100/100 [==============================] - 77s 769ms/step - loss: 0.3927
# Epoch 32/100
# 100/100 [==============================] - 77s 767ms/step - loss: 0.3926
# Epoch 33/100
# 100/100 [==============================] - 77s 766ms/step - loss: 0.3924
# Epoch 34/100
# 100/100 [==============================] - 77s 767ms/step - loss: 0.3923
# Epoch 35/100
# 100/100 [==============================] - 77s 769ms/step - loss: 0.3922
# Epoch 36/100
# 100/100 [==============================] - 77s 770ms/step - loss: 0.3921
# Epoch 37/100
# 100/100 [==============================] - 77s 768ms/step - loss: 0.3920
# Epoch 38/100
# 100/100 [==============================] - 77s 769ms/step - loss: 0.3919
# Epoch 39/100
# 100/100 [==============================] - 76s 764ms/step - loss: 0.3918
# Epoch 40/100
# 100/100 [==============================] - 77s 766ms/step - loss: 0.3917
# Epoch 41/100
# 100/100 [==============================] - 77s 769ms/step - loss: 0.3916
# Epoch 42/100
# 100/100 [==============================] - 77s 769ms/step - loss: 0.3915
# Epoch 43/100
# 100/100 [==============================] - 77s 769ms/step - loss: 0.3914
# Epoch 44/100
# 100/100 [==============================] - 77s 769ms/step - loss: 0.3913
# Epoch 45/100
# 100/100 [==============================] - 77s 766ms/step - loss: 0.3912
# Epoch 46/100
# 100/100 [==============================] - 77s 767ms/step - loss: 0.3911
# Epoch 47/100
# 100/100 [==============================] - 77s 766ms/step - loss: 0.3910
# Epoch 48/100
# 100/100 [==============================] - 76s 764ms/step - loss: 0.3909
# Epoch 49/100
# 100/100 [==============================] - 77s 766ms/step - loss: 0.3909
# Epoch 50/100
# 100/100 [==============================] - 77s 769ms/step - loss: 0.3908
# Epoch 51/100
# 100/100 [==============================] - 77s 767ms/step - loss: 0.3907
# Epoch 52/100
# 100/100 [==============================] - 77s 767ms/step - loss: 0.3906
# Epoch 53/100
# 100/100 [==============================] - 77s 769ms/step - loss: 0.3905
# Epoch 54/100
# 100/100 [==============================] - 77s 768ms/step - loss: 0.3904
# Epoch 55/100
# 100/100 [==============================] - 77s 770ms/step - loss: 0.3904
# Epoch 56/100
# 100/100 [==============================] - 77s 765ms/step - loss: 0.3903
# Epoch 57/100
# 100/100 [==============================] - 77s 770ms/step - loss: 0.3902
# Epoch 58/100
# 100/100 [==============================] - 77s 768ms/step - loss: 0.3901
# Epoch 59/100
# 100/100 [==============================] - 77s 769ms/step - loss: 0.3900
# Epoch 60/100
# 100/100 [==============================] - 77s 767ms/step - loss: 0.3900
# Epoch 61/100
# 100/100 [==============================] - 77s 769ms/step - loss: 0.3899
# Epoch 62/100
# 100/100 [==============================] - 77s 770ms/step - loss: 0.3898
# Epoch 63/100
# 100/100 [==============================] - 77s 770ms/step - loss: 0.3898
# Epoch 64/100
# 100/100 [==============================] - 77s 768ms/step - loss: 0.3897
# Epoch 65/100
# 100/100 [==============================] - 77s 768ms/step - loss: 0.3896
# Epoch 66/100
# 100/100 [==============================] - 77s 766ms/step - loss: 0.3895
# Epoch 67/100
# 100/100 [==============================] - 76s 765ms/step - loss: 0.3895
# Epoch 68/100
# 100/100 [==============================] - 77s 768ms/step - loss: 0.3894
# Epoch 69/100
# 100/100 [==============================] - 77s 769ms/step - loss: 0.3893
# Epoch 70/100
# 100/100 [==============================] - 77s 766ms/step - loss: 0.3892
# Epoch 71/100
# 100/100 [==============================] - 77s 770ms/step - loss: 0.3892
# Epoch 72/100
# 100/100 [==============================] - 77s 769ms/step - loss: 0.3891
# Epoch 73/100
# 100/100 [==============================] - 77s 768ms/step - loss: 0.3890
# Epoch 74/100
# 100/100 [==============================] - 77s 769ms/step - loss: 0.3890
# Epoch 75/100
# 100/100 [==============================] - 77s 765ms/step - loss: 0.3889
# Epoch 76/100
# 100/100 [==============================] - 77s 768ms/step - loss: 0.3888
# Epoch 77/100
# 100/100 [==============================] - 77s 767ms/step - loss: 0.3887
# Epoch 78/100
# 100/100 [==============================] - 77s 768ms/step - loss: 0.3887
# Epoch 79/100
# 100/100 [==============================] - 77s 767ms/step - loss: 0.3886
# Epoch 80/100
# 100/100 [==============================] - 76s 765ms/step - loss: 0.3885
# Epoch 81/100
# 100/100 [==============================] - 77s 769ms/step - loss: 0.3885
# Epoch 82/100
# 100/100 [==============================] - 77s 767ms/step - loss: 0.3884
# Epoch 83/100
# 100/100 [==============================] - 77s 767ms/step - loss: 0.3883
# Epoch 84/100
# 100/100 [==============================] - 76s 765ms/step - loss: 0.3883
# Epoch 85/100
# 100/100 [==============================] - 77s 767ms/step - loss: 0.3882
# Epoch 86/100
# 100/100 [==============================] - 77s 767ms/step - loss: 0.3881
# Epoch 87/100
# 100/100 [==============================] - 76s 764ms/step - loss: 0.3881
# Epoch 88/100
# 100/100 [==============================] - 77s 769ms/step - loss: 0.3880
# Epoch 89/100
# 100/100 [==============================] - 77s 766ms/step - loss: 0.3879
# Epoch 90/100
# 100/100 [==============================] - 77s 769ms/step - loss: 0.3879
# Epoch 91/100
# 100/100 [==============================] - 77s 770ms/step - loss: 0.3878
# Epoch 92/100
# 100/100 [==============================] - 77s 769ms/step - loss: 0.3877
# Epoch 93/100
# 100/100 [==============================] - 77s 769ms/step - loss: 0.3877
# Epoch 94/100
# 100/100 [==============================] - 77s 767ms/step - loss: 0.3876
# Epoch 95/100
# 100/100 [==============================] - 77s 767ms/step - loss: 0.3875
# Epoch 96/100
# 100/100 [==============================] - 77s 768ms/step - loss: 0.3875
# Epoch 97/100
# 100/100 [==============================] - 77s 770ms/step - loss: 0.3874
# Epoch 98/100
# 100/100 [==============================] - 77s 768ms/step - loss: 0.3874
# Epoch 99/100
# 100/100 [==============================] - 77s 770ms/step - loss: 0.3873
# Epoch 100/100
# 100/100 [==============================] - 77s 768ms/step - loss: 0.3872
# (1, 1024, 256, 1)
# (1024, 1024)
# MSE: 0.004027366513046403
# 9.7039134e-08
# 0.9886064

# %%
for data in list_data:
    if data.shape[1] == 256:
        d = data
        
row, col = d.shape

autoencoder = load_model('/data/multimodal/dicty/experiment_' + str(numOfExperiment) +'_cnn_expr.h5')

predict = autoencoder.predict(d.reshape(1, row, col, 1))
print(predict.shape)
print(data.shape)
mse = mean_squared_error(d, predict.reshape(row, col))
print('MSE: ' + str(mse))

import matplotlib.pyplot as plt
import matplotlib as mpl

path = '/mag/Experiments/Results/'+ str(numOfExperiment) + '/dicty/'

# color_pack = 'Blues'
# color_pack = 'jet'
color_pack = 'viridis'
color_pack2 = 'RdBu'
# color_pack = 'binary'
# color_pack = 'PuOr'
# color_pack = 'rainbow'

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(25, 6))
org_data = d
predict = predict.reshape((row, col))

print(np.min(predict))
print(np.max(predict))


ax = axes[0]
im = ax.imshow(org_data, vmin=0, vmax=1, cmap=plt.cm.get_cmap(color_pack))

ax = axes[1]
im2 = ax.imshow(predict, vmin=np.min(predict), vmax=np.max(predict), cmap=plt.cm.get_cmap(color_pack2))

#     ax = axes[2]
#     im = ax.imshow(predict - org_data, vmin=-1, vmax=1, cmap=plt.cm.get_cmap(color_pack))
     
# fig.colorbar(im, ax=axes.ravel().tolist())
#     cax,kw = mpl.colorbar.make_axes([ax for ax in axes.flat])
cax,kw = mpl.colorbar.make_axes([axes[0]])
cax2,kw2 = mpl.colorbar.make_axes([axes[1]])
cba = plt.colorbar(im, cax=cax, **kw)
cbb = plt.colorbar(im2, cax=cax2, **kw2)

plt.savefig(path + 'experiment' + str(numOfExperiment) + '_expr_org_vs_predict.png')

plt.show()
# Out:
# (1, 1024, 256, 1)
# (1024, 1024)
# MSE: 0.004027366513046403
# 9.7039134e-08
# 0.9886064

# %%
def shuffle_data(org_data):
    row, col = org_data.shape
    tmp_data = org_data.flatten()
    np.random.shuffle(tmp_data)  # shuffle org data
    return np.array(tmp_data).reshape(row, col)

    
shuffled_data = shuffle_data(org_data)
shuffled_predict = autoencoder.predict(d.reshape(1, row, col, 1))

outputHeader = 'Data\t\t'
outputHeader += 'Density\t\t'
outputHeader += 'Predict\t\t'
outputHeader += 'BaseLine\t'
outputHeader += 'AVG Mean\t'
outputHeader += 'Predict (mean)\t'
# outputHeader += 'Predict (min)\t'
# outputHeader += 'Predict (max)\t'
print(outputHeader)

#         print('Data \t\t\tDensity \tPredict \tBaseLine \tAVG Mean')
row, col = org_data.shape 
mse = mean_squared_error(org_data.flatten(), predict.flatten())
mse_base_line = mean_squared_error(shuffled_data.flatten(), shuffled_predict.flatten())

non_zeros = org_data.flatten()
non_zeros[org_data.flatten() > 0] = 1
org_mean = round(np.mean(non_zeros * org_data.flatten()), 5)
predict_mean = round(np.mean(non_zeros * predict.flatten()), 5)

outputBody = '(' + str(row) + ',' + str(col) + ') ' + '\t'
outputBody += str(round((np.count_nonzero(org_data)/(row * col)) * 100, 2)) + '% \t\t'
outputBody += str(round(mse * 100, 5)) + '% \t'
outputBody += str(round(mse_base_line * 100, 5)) + '% '+ '\t'
outputBody += str(org_mean) + '\t\t'
outputBody += str(predict_mean) + '\t\t'
# outputBody += str(round(min(predict.flatten()), 5)) + '\t\t'
# outputBody += str(round(max(predict.flatten()), 5)) + '\t'
print(outputBody)
# Out:
# Data		Density		Predict		BaseLine	AVG Mean	Predict (mean)
# (1024,256) 	95.4% 		0.40274% 	6.36816% 	0.82382		0.82642

# %%
def data_generator(filenames, org_data, batch_size=1):
    # n_pack => 100 samples of matrix
    # n_pack = batch_size
    files = []              # different files
    num_packs = []          # subpacked inside of file
    for filename in filenames:
        f = np.load(filename)
        files.append(f)
        num_packs.append(f.files)
    
    counter = 0
    while True:
        x = []
        y = []
        for i in range(len(files)):
            for j in range(batch_size):
                rand_num = np.random.randint(len(num_packs[i]))
                f = files[i]
                pack = num_packs[i]
                data = f[pack[rand_num]] 
    #             new_data = top_N_rows(data)
    #             x.append(new_data)

                x.append(f[pack[rand_num]])
                y.append(org_data)
            
        x = np.asarray(x)
        y = np.asarray(y)
        
        x = x[:, 0, :, :, :]
        y = y[:, 0, :, :, :]
        
        yield ([x], [y])
        
        if counter >= batch_size:
            counter = 0

d = []
file = 'ppi'

for data in list_data:
    if data.shape[1] == 1024:
        d = data
        
row, col = d.shape
input_img = Input(shape=(row, col, 1))  # adapt this if using `channels_first` image data format
x = Conv2D(128, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2, 2), padding='same')(x)

ae = Flatten()(encoded)
ae = Dense(1024, activation='relu')(ae)
ae = Dense(512, activation='relu')(ae)
ae = Dense(256, activation='relu')(ae)
ae = Dense(128, activation='relu')(ae)
ae = Dense(64, activation='relu')(ae)
ae = Dense(128, activation='relu')(ae)
ae = Dense(256, activation='relu')(ae)
ae = Dense(512, activation='relu')(ae)
ae = Dense(1024, activation='relu')(ae) 
ae = Reshape((32, 32, 1))(ae)


# at this point the representation is (4, 4, 8) i.e. 128-dimensional

x = Conv2D(8, (3, 3), activation='relu', padding='same')(ae)
x = UpSampling2D((2, 2))(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = Model(input_img, decoded)
sgd = SGD(lr=0.001, decay=1e-6)
# autoencoder.compile(optimizer=sgd, loss='mse')
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')
autoencoder.summary() 
folder = '/data/samples/cnn/dicty/'
autoencoder.fit_generator(
    data_generator([folder+file+'.npz'], d.reshape(1, row, col, 1), 4), 
    steps_per_epoch=400, 
    epochs=100
)

autoencoder.save('/data/multimodal/dicty/experiment_'+ str(numOfExperiment) + '_cnn_' + file +'.h5')

predict = autoencoder.predict(d.reshape(1, row, col, 1))
print(predict.shape)
print(data.shape)
mse = mean_squared_error(d, predict.reshape(row, col))
print('MSE: ' + str(mse))

import matplotlib.pyplot as plt
import matplotlib as mpl

path = '/mag/Experiments/Results/'+ str(numOfExperiment) + '/dicty/'

# color_pack = 'Blues'
# color_pack = 'jet'
color_pack = 'viridis'
color_pack2 = 'RdBu'
# color_pack = 'binary'
# color_pack = 'PuOr'
# color_pack = 'rainbow'

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(25, 6))
org_data = d
predict = predict.reshape((row, col))

print(np.min(predict))
print(np.max(predict))


ax = axes[0]
im = ax.imshow(org_data, vmin=0, vmax=1, cmap=plt.cm.get_cmap(color_pack))

ax = axes[1]
im2 = ax.imshow(predict, vmin=np.min(predict), vmax=np.max(predict), cmap=plt.cm.get_cmap(color_pack2))

#     ax = axes[2]
#     im = ax.imshow(predict - org_data, vmin=-1, vmax=1, cmap=plt.cm.get_cmap(color_pack))

# fig.colorbar(im, ax=axes.ravel().tolist())
#     cax,kw = mpl.colorbar.make_axes([ax for ax in axes.flat])
cax,kw = mpl.colorbar.make_axes([axes[0]])
cax2,kw2 = mpl.colorbar.make_axes([axes[1]])
cba = plt.colorbar(im, cax=cax, **kw)
cbb = plt.colorbar(im2, cax=cax2, **kw2)

plt.savefig(path + 'experiment' + str(numOfExperiment) + '_' + file + '_org_vs_predict.png')

plt.show()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         (None, 1024, 1024, 1)     0
# _________________________________________________________________
# conv2d_77 (Conv2D)           (None, 1024, 1024, 128)   1280
# _________________________________________________________________
# max_pooling2d_35 (MaxPooling (None, 512, 512, 128)     0
# _________________________________________________________________
# conv2d_78 (Conv2D)           (None, 512, 512, 64)      73792
# _________________________________________________________________
# max_pooling2d_36 (MaxPooling (None, 256, 256, 64)      0
# _________________________________________________________________
# conv2d_79 (Conv2D)           (None, 256, 256, 32)      18464
# _________________________________________________________________
# max_pooling2d_37 (MaxPooling (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_80 (Conv2D)           (None, 128, 128, 16)      4624
# _________________________________________________________________
# max_pooling2d_38 (MaxPooling (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_81 (Conv2D)           (None, 64, 64, 8)         1160
# _________________________________________________________________
# max_pooling2d_39 (MaxPooling (None, 32, 32, 8)         0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_63 (Dense)             (None, 1024)              8389632
# _________________________________________________________________
# dense_64 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dense_65 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_66 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_67 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_68 (Dense)             (None, 128)               8320
# _________________________________________________________________
# dense_69 (Dense)             (None, 256)               33024
# _________________________________________________________________
# dense_70 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_71 (Dense)             (None, 1024)              525312
# _________________________________________________________________
# reshape_7 (Reshape)          (None, 32, 32, 1)         0
# _________________________________________________________________
# conv2d_82 (Conv2D)           (None, 32, 32, 8)         80
# _________________________________________________________________
# up_sampling2d_35 (UpSampling (None, 64, 64, 8)         0
# _________________________________________________________________
# conv2d_83 (Conv2D)           (None, 64, 64, 16)        1168
# _________________________________________________________________
# up_sampling2d_36 (UpSampling (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_84 (Conv2D)           (None, 128, 128, 32)      4640
# _________________________________________________________________
# up_sampling2d_37 (UpSampling (None, 256, 256, 32)      0
# _________________________________________________________________
# conv2d_85 (Conv2D)           (None, 256, 256, 64)      18496
# _________________________________________________________________
# up_sampling2d_38 (UpSampling (None, 512, 512, 64)      0
# _________________________________________________________________
# conv2d_86 (Conv2D)           (None, 512, 512, 128)     73856
# _________________________________________________________________
# up_sampling2d_39 (UpSampling (None, 1024, 1024, 128)   0
# _________________________________________________________________
# conv2d_87 (Conv2D)           (None, 1024, 1024, 1)     1153
# =================================================================
# Total params: 9,983,865
# Trainable params: 9,983,865
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 400/400 [==============================] - 302s 756ms/step - loss: 0.1082
# Epoch 2/100
# 400/400 [==============================] - 300s 749ms/step - loss: 0.0944
# Epoch 3/100
# 400/400 [==============================] - 300s 749ms/step - loss: 0.0939
# Epoch 4/100
# 357/400 [=========================>....] - ETA: 32s - loss: 0.0936

# %%
for data in list_data:
    if data.shape[1] == 1024:
        d = data
        
row, col = d.shape
file = 'ppi'
autoencoder = load_model('/data/multimodal/dicty/experiment_' + str(numOfExperiment) + '_cnn_' + file + '.h5')

predict = autoencoder.predict(d.reshape(1, row, col, 1))
print(predict.shape)
print(data.shape)
mse = mean_squared_error(d, predict.reshape(row, col))
print('MSE: ' + str(mse))

import matplotlib.pyplot as plt
import matplotlib as mpl

path = '/mag/Experiments/Results/'+ str(numOfExperiment) + '/dicty/'

# color_pack = 'Blues'
# color_pack = 'jet'
color_pack = 'viridis'
color_pack2 = 'RdBu'
# color_pack = 'binary'
# color_pack = 'PuOr'
# color_pack = 'rainbow'

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(25, 6))
org_data = d
predict = predict.reshape((row, col))

print(np.min(predict))
print(np.max(predict))


ax = axes[0]
im = ax.imshow(org_data, vmin=0, vmax=1, cmap=plt.cm.get_cmap(color_pack))

ax = axes[1]
im2 = ax.imshow(predict, vmin=np.min(predict), vmax=np.max(predict), cmap=plt.cm.get_cmap(color_pack2))

#     ax = axes[2]
#     im = ax.imshow(predict - org_data, vmin=-1, vmax=1, cmap=plt.cm.get_cmap(color_pack))

# fig.colorbar(im, ax=axes.ravel().tolist())
#     cax,kw = mpl.colorbar.make_axes([ax for ax in axes.flat])
cax,kw = mpl.colorbar.make_axes([axes[0]])
cax2,kw2 = mpl.colorbar.make_axes([axes[1]])
cba = plt.colorbar(im, cax=cax, **kw)
cbb = plt.colorbar(im2, cax=cax2, **kw2)

plt.savefig(path + 'experiment' + str(numOfExperiment) + '_' + file + '_org_vs_predict.png')

plt.show()
# Out:
# (1, 1024, 1024, 1)
# (1024, 1024)
# MSE: 0.010334588283751275
# 0.0
# 1.0

# %%
def shuffle_data(org_data):
    row, col = org_data.shape
    tmp_data = org_data.flatten()
    np.random.shuffle(tmp_data)  # shuffle org data
    return np.array(tmp_data).reshape(row, col)

    
shuffled_data = shuffle_data(org_data)
shuffled_predict = autoencoder.predict(d.reshape(1, row, col, 1))

outputHeader = 'Data\t\t'
outputHeader += 'Density\t\t'
outputHeader += 'Predict\t\t'
outputHeader += 'BaseLine\t'
outputHeader += 'AVG Mean\t'
outputHeader += 'Predict (mean)\t'
# outputHeader += 'Predict (min)\t'
# outputHeader += 'Predict (max)\t'
print(outputHeader)

#         print('Data \t\t\tDensity \tPredict \tBaseLine \tAVG Mean')
row, col = org_data.shape 
mse = mean_squared_error(org_data.flatten(), predict.flatten())
mse_base_line = mean_squared_error(shuffled_data.flatten(), shuffled_predict.flatten())

non_zeros = org_data.flatten()
non_zeros[org_data.flatten() > 0] = 1
org_mean = round(np.mean(non_zeros * org_data.flatten()), 5)
predict_mean = round(np.mean(non_zeros * predict.flatten()), 5)

outputBody = '(' + str(row) + ',' + str(col) + ') ' + '\t'
outputBody += str(round((np.count_nonzero(org_data)/(row * col)) * 100, 2)) + '% \t\t'
outputBody += str(round(mse * 100, 5)) + '% \t'
outputBody += str(round(mse_base_line * 100, 5)) + '% '+ '\t'
outputBody += str(org_mean) + '\t\t'
outputBody += str(predict_mean) + '\t\t'
# outputBody += str(round(min(predict.flatten()), 5)) + '\t\t'
# outputBody += str(round(max(predict.flatten()), 5)) + '\t'
print(outputBody)
# Out:
# Data		Density		Predict		BaseLine	AVG Mean	Predict (mean)
# (1024,1024) 	3.04% 		1.03346% 	3.67344% 	0.02452		0.01652
