# %%
import sys
sys.path.append('/mag/scripts')

from relationGraph import Relation, RelationGraph, MatrixOfRelationGraph
from autoencoder import seedy, AutoEncoder
import utilityFunctions as uf
from main import test_build_relation_graph_with_symertic_data, test_convert_graph_to_2D_matrix, test_get_matix_for_autoencoder, test_autoencoder
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
from base import load_source
from base2 import load_dicty, load_pharma
import utilityFunctions as uf
import autoencoder as ae
import multimodal as mm


from os.path import join
import numpy as np
import multiprocessing

from scipy.spatial.distance import pdist, squareform
from fastcluster import linkage
import matplotlib.pyplot as plt

from tensorflow.keras.layers import Input, Dense, Embedding, Layer, Reshape, UpSampling2D, Flatten, Masking, Dropout, concatenate, Conv2D, MaxPooling2D, BatchNormalization, Lambda
from tensorflow.keras.models import Model, Sequential, load_model
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping
from tensorflow import set_random_seed
from tensorflow.keras.optimizers import SGD
from tensorflow.keras import backend as K
from sklearn.metrics import mean_squared_error

numOfExperiment = 17
path_data = '/data/samples/multiple_inputs_clustering/dicty/'

# %load_ext autoreload
# %autoreload 2

# %%
graph1 = load_dicty('clustering', 2)
# graph2 = load_pharma()
# Out:
# 0.0
# 1.0
#
# 0.0
# 1.0
#
# 0.0
# 1.0
# -------------RelationGraph-------------
# Experimental condition	282
# 0
# 1	expr-(1024, 256)
# Gene	1219
# 3	ann-(1024, 128), expr-(1024, 256), ppi-(1024, 1024)
# 0
# GO term	116
# 0
# 1	ann-(1024, 128)

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

# display data
already_used = set()
list_data = []
for obj in graph1.objects.values():
    for relation in obj.relation_x:
        if relation.name not in already_used:
            list_data.append(relation.matrix)
            already_used.add(relation.name)
    
    for relation in obj.relation_y:
        if relation.name not in already_used:
            list_data.append(relation.matrix)
            already_used.add(relation.name)
        

color_pack = 'viridis'

for data in list_data:
#     fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(25, 6))
    plt.matshow(data, cmap=plt.cm.Blues)

    plt.show()

# %%
def sample_generator4(matrix, num_of_samples=1, density=0.8):
    # input  => sample_generator4([1219, 116], 1000, 0.8)
    # output => [1000, 1219, 116, 1]
    x_size, y_size = matrix.shape
    data = np.zeros((0, x_size, y_size, 1))
    print('Random seed: '  + str(np.random.randint(y_size)))
    
    while num_of_samples > 0:
        tmp_matrix = np.copy(matrix)
        for row in tmp_matrix:
            indices = np.random.choice(y_size, round(y_size * density), replace=False)
            mask = np.isin(np.arange(y_size), indices, invert=True)
            row[mask] = 0
            
        data = np.r_[data, tmp_matrix.reshape(1, x_size, y_size, 1)]                
        num_of_samples -= 1

    return data


def mp_worker(arr):
#     new_data = uf.sample_generator3(data, num_of_samples=100, density=0.7, 1)
    np.random.seed(arr[3])
    new_data = sample_generator4(arr[0], num_of_samples=arr[1], density=arr[2])
    return new_data


def data_generator_2(data, n_samples, pools, density, filename):
    batch_size = 1
    p = multiprocessing.Pool(pools)
    gen_samples = np.zeros((0, data.shape[0] * data.shape[1]))
    iterations = int(np.round((n_samples -1)/batch_size)) + 1
    
    params = [[data, batch_size, density, i] for i in range(iterations)]
    
    i = 1
    f = uf.my_savez(filename)
    for result in p.imap(mp_worker, params):
        print('samples: ' + str(i * batch_size))
        i+=1
        f.savez(result)
    f.close()


n_samples=10000
pools=6
density= .7

graph = graph1
# graph = graph2
for data in list_data:
    if data.shape[1] == 128:
        folder = '/data/samples/cnn/dicty/'
        data_generator_2(data, n_samples, pools, density, folder + 'ann.npz')
    elif data.shape[1] == 256:
        folder = '/data/samples/cnn/dicty/'
        data_generator_2(data, n_samples, pools, density, folder + 'expr.npz')
    elif data.shape[1] == 1024:
        folder = '/data/samples/cnn/dicty/'
        data_generator_2(data, n_samples, pools, density, folder + 'ppi.npz')
# Out:
# Random seed: 172
# Random seed: 37
# Random seed: 168
# Random seed: 106
# Random seed: 122
# Random seed: 99
# Random seed: 138
# Random seed: 175
# Random seed: 195
# Random seed: 126
# Random seed: 9
# Random seed: 153
# Random seed: 75
# Random seed: 82
# Random seed: 107
# Random seed: 200
# samples: 1
# samples: 2
# samples: 3
# samples: 4
# samples: 5
# samples: 6
# samples: 7
# samples: 8
# samples: 9
# samples: 10
# Random seed: 169
# Random seed: 111
# Random seed: 42
# Random seed: 93
# Random seed: 99
# Random seed: 201
# Random seed: 117
# Random seed: 83
# Random seed: 162
# Random seed: 132
# Random seed: 53
# Random seed: 19
# samples: 11
# samples: 12
# samples: 13
# samples: 14
# samples: 15
# samples: 16
# samples: 17
# samples: 18
# samples: 19
# samples: 20
# Random seed: 1
# Random seed: 213
# Random seed: 37
# Random seed: 210
# Random seed: 215
# Random seed: 20
# Random seed: 161
# Random seed: 201
# Random seed: 133
# samples: 21
# samples: 22
# samples: 23
# ...

# %%
def data_generator(filenames, org_data, batch_size=1):
    # n_pack => 100 samples of matrix
    # n_pack = batch_size
    files = []              # different files
    num_packs = []          # subpacked inside of file
    for filename in filenames:
        f = np.load(filename)
        files.append(f)
        num_packs.append(f.files)
    
    counter = 0
    while True:
        x = []
        y = []
        for i in range(len(files)):
            for j in range(batch_size):
                rand_num = np.random.randint(len(num_packs[i]))
                f = files[i]
                pack = num_packs[i]
                data = f[pack[rand_num]] 
    #             new_data = top_N_rows(data)
    #             x.append(new_data)

                x.append(f[pack[rand_num]])
                y.append(org_data)
            
        x = np.asarray(x)
        y = np.asarray(y)
        
        x = x[:, 0, :, :, :]
        y = y[:, 0, :, :, :]
        
        yield ([x], [y])
        
        if counter >= batch_size:
            counter = 0

d = []

for data in list_data:
    if data.shape[1] == 128:
        d = data
        
row, col = d.shape
input_img = Input(shape=(row, col, 1))  # adapt this if using `channels_first` image data format
x = Conv2D(128, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2, 2), padding='same')(x)

ae = Flatten()(encoded)
ae = Dense(1024, activation='relu')(ae)
ae = Dense(512, activation='relu')(ae)
ae = Dense(256, activation='relu')(ae)
ae = Dense(128, activation='relu')(ae)
ae = Dense(64, activation='relu')(ae)
ae = Dense(128, activation='relu')(ae)
ae = Dense(256, activation='relu')(ae)
ae = Dense(512, activation='relu')(ae)
# ae = Dense(1024, activation='relu')(ae)
ae = Reshape((64, 8, 1))(ae)


# at this point the representation is (4, 4, 8) i.e. 128-dimensional

x = Conv2D(16, (3, 3), activation='relu', padding='same')(ae)
x = UpSampling2D((2, 2))(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = Model(input_img, decoded)
sgd = SGD(lr=0.001, decay=1e-6)
# autoencoder.compile(optimizer=sgd, loss='mse')
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')
autoencoder.summary() 
folder = '/data/samples/cnn/dicty/'
autoencoder.fit_generator(
    data_generator([folder+'ann.npz'], d.reshape(1, row, col, 1), 16), 
    steps_per_epoch=100, 
    epochs=100
)

autoencoder.save('/data/multimodal/dicty/experiment_' + str(numOfExperiment) +'_cnn_ann.h5')

predict = autoencoder.predict(d.reshape(1, row, col, 1))
print(predict.shape)
print(data.shape)
mse = mean_squared_error(d, predict.reshape(row, col))
print('MSE: ' + str(mse))

import matplotlib.pyplot as plt
import matplotlib as mpl

path = '/mag/Experiments/Results/'+ str(numOfExperiment) + '/dicty/'

# color_pack = 'Blues'
# color_pack = 'jet'
color_pack = 'viridis'
color_pack2 = 'RdBu'
# color_pack = 'binary'
# color_pack = 'PuOr'
# color_pack = 'rainbow'

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(25, 6))
org_data = d
predict = predict.reshape((row, col))

print(np.min(predict))
print(np.max(predict))


ax = axes[0]
im = ax.imshow(org_data, vmin=0, vmax=1, cmap=plt.cm.get_cmap(color_pack))

ax = axes[1]
im2 = ax.imshow(predict, vmin=np.min(predict), vmax=np.max(predict), cmap=plt.cm.get_cmap(color_pack2))

#     ax = axes[2]
#     im = ax.imshow(predict - org_data, vmin=-1, vmax=1, cmap=plt.cm.get_cmap(color_pack))
     
# fig.colorbar(im, ax=axes.ravel().tolist())
#     cax,kw = mpl.colorbar.make_axes([ax for ax in axes.flat])
cax,kw = mpl.colorbar.make_axes([axes[0]])
cax2,kw2 = mpl.colorbar.make_axes([axes[1]])
cba = plt.colorbar(im, cax=cax, **kw)
cbb = plt.colorbar(im2, cax=cax2, **kw2)

plt.savefig(path + 'experiment' + str(numOfExperiment) + '_ann_org_vs_predict.png')

plt.show()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 1024, 128, 1)      0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 1024, 128, 128)    1280
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 512, 64, 128)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 512, 64, 64)       73792
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 256, 32, 64)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 256, 32, 32)       18464
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 128, 16, 32)       0
# ...

# %%
autoencoder = load_model('/data/multimodal/dicty/experiment_' + str(numOfExperiment) +'_cnn_ann.h5')

predict = autoencoder.predict(d.reshape(1, row, col, 1))
print(predict.shape)
print(data.shape)
mse = mean_squared_error(d, predict.reshape(row, col))
print('MSE: ' + str(mse))

import matplotlib.pyplot as plt
import matplotlib as mpl

path = '/mag/Experiments/Results/'+ str(numOfExperiment) + '/dicty/'

# color_pack = 'Blues'
# color_pack = 'jet'
color_pack = 'viridis'
color_pack2 = 'RdBu'
# color_pack = 'binary'
# color_pack = 'PuOr'
# color_pack = 'rainbow'

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(25, 6))
org_data = d
predict = predict.reshape((row, col))

print(np.min(predict))
print(np.max(predict))


ax = axes[0]
im = ax.imshow(org_data, vmin=0, vmax=1, cmap=plt.cm.get_cmap(color_pack))

ax = axes[1]
im2 = ax.imshow(predict, vmin=np.min(predict), vmax=np.max(predict), cmap=plt.cm.get_cmap(color_pack2))

#     ax = axes[2]
#     im = ax.imshow(predict - org_data, vmin=-1, vmax=1, cmap=plt.cm.get_cmap(color_pack))
     
# fig.colorbar(im, ax=axes.ravel().tolist())
#     cax,kw = mpl.colorbar.make_axes([ax for ax in axes.flat])
cax,kw = mpl.colorbar.make_axes([axes[0]])
cax2,kw2 = mpl.colorbar.make_axes([axes[1]])
cba = plt.colorbar(im, cax=cax, **kw)
cbb = plt.colorbar(im2, cax=cax2, **kw2)

plt.savefig(path + 'experiment' + str(numOfExperiment) + '_ann_org_vs_predict.png')

plt.show()
# Out:
# (1, 1024, 128, 1)
# (1024, 1024)
# MSE: 0.00416115252299418
# 0.0
# 1.0

# %%
def data_generator(filenames, org_data, batch_size=1):
    # n_pack => 100 samples of matrix
    # n_pack = batch_size
    files = []              # different files
    num_packs = []          # subpacked inside of file
    for filename in filenames:
        f = np.load(filename)
        files.append(f)
        num_packs.append(f.files)
    
    counter = 0
    while True:
        x = []
        y = []
        for i in range(len(files)):
            for j in range(batch_size):
                rand_num = np.random.randint(len(num_packs[i]))
                f = files[i]
                pack = num_packs[i]
                data = f[pack[rand_num]] 
    #             new_data = top_N_rows(data)
    #             x.append(new_data)

                x.append(f[pack[rand_num]])
                y.append(org_data)
            
        x = np.asarray(x)
        y = np.asarray(y)
        
        x = x[:, 0, :, :, :]
        y = y[:, 0, :, :, :]
        
        yield ([x], [y])
        
        if counter >= batch_size:
            counter = 0

d = []
file = 'expr'

for data in list_data:
    if data.shape[1] == 256:
        d = data
        
row, col = d.shape
input_img = Input(shape=(row, col, 1))  # adapt this if using `channels_first` image data format
x = Conv2D(128, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2, 2), padding='same')(x)

ae = Flatten()(encoded)
ae = Dense(1024, activation='relu')(ae)
ae = Dense(512, activation='relu')(ae)
ae = Dense(256, activation='relu')(ae)
ae = Dense(128, activation='relu')(ae)
ae = Dense(64, activation='relu')(ae)
ae = Dense(128, activation='relu')(ae)
ae = Dense(256, activation='relu')(ae)
ae = Dense(512, activation='relu')(ae)
ae = Dense(1024, activation='relu')(ae)
ae = Reshape((64, 16, 1))(ae)


# at this point the representation is (4, 4, 8) i.e. 128-dimensional

x = Conv2D(16, (3, 3), activation='relu', padding='same')(ae)
x = UpSampling2D((2, 2))(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = Model(input_img, decoded)
sgd = SGD(lr=0.001, decay=1e-6)
# autoencoder.compile(optimizer=sgd, loss='mse')
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')
autoencoder.summary() 
folder = '/data/samples/cnn/dicty/'
autoencoder.fit_generator(
    data_generator([folder+file+'.npz'], d.reshape(1, row, col, 1), 16), 
    steps_per_epoch=100, 
    epochs=100
)

autoencoder.save('/data/multimodal/dicty/experiment_'+ str(numOfExperiment) + '_cnn_' + file +'.h5')

predict = autoencoder.predict(d.reshape(1, row, col, 1))
print(predict.shape)
print(data.shape)
mse = mean_squared_error(d, predict.reshape(row, col))
print('MSE: ' + str(mse))

import matplotlib.pyplot as plt
import matplotlib as mpl

path = '/mag/Experiments/Results/'+ str(numOfExperiment) + '/dicty/'

# color_pack = 'Blues'
# color_pack = 'jet'
color_pack = 'viridis'
color_pack2 = 'RdBu'
# color_pack = 'binary'
# color_pack = 'PuOr'
# color_pack = 'rainbow'

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(25, 6))
org_data = d
predict = predict.reshape((row, col))

print(np.min(predict))
print(np.max(predict))


ax = axes[0]
im = ax.imshow(org_data, vmin=0, vmax=1, cmap=plt.cm.get_cmap(color_pack))

ax = axes[1]
im2 = ax.imshow(predict, vmin=np.min(predict), vmax=np.max(predict), cmap=plt.cm.get_cmap(color_pack2))

#     ax = axes[2]
#     im = ax.imshow(predict - org_data, vmin=-1, vmax=1, cmap=plt.cm.get_cmap(color_pack))

# fig.colorbar(im, ax=axes.ravel().tolist())
#     cax,kw = mpl.colorbar.make_axes([ax for ax in axes.flat])
cax,kw = mpl.colorbar.make_axes([axes[0]])
cax2,kw2 = mpl.colorbar.make_axes([axes[1]])
cba = plt.colorbar(im, cax=cax, **kw)
cbb = plt.colorbar(im2, cax=cax2, **kw2)

plt.savefig(path + 'experiment' + str(numOfExperiment) + '_' + file + '_org_vs_predict.png')

plt.show()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 1024, 256, 1)      0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 1024, 256, 128)    1280
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 512, 128, 128)     0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 512, 128, 64)      73792
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 256, 64, 64)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 256, 64, 32)       18464
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 128, 32, 32)       0
# ...

# %%
autoencoder = load_model('/data/multimodal/dicty/experiment_' + str(numOfExperiment) +'_cnn_expr.h5')

predict = autoencoder.predict(d.reshape(1, row, col, 1))
print(predict.shape)
print(data.shape)
mse = mean_squared_error(d, predict.reshape(row, col))
print('MSE: ' + str(mse))

import matplotlib.pyplot as plt
import matplotlib as mpl

path = '/mag/Experiments/Results/'+ str(numOfExperiment) + '/dicty/'

# color_pack = 'Blues'
# color_pack = 'jet'
color_pack = 'viridis'
color_pack2 = 'RdBu'
# color_pack = 'binary'
# color_pack = 'PuOr'
# color_pack = 'rainbow'

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(25, 6))
org_data = d
predict = predict.reshape((row, col))

print(np.min(predict))
print(np.max(predict))


ax = axes[0]
im = ax.imshow(org_data, vmin=0, vmax=1, cmap=plt.cm.get_cmap(color_pack))

ax = axes[1]
im2 = ax.imshow(predict, vmin=np.min(predict), vmax=np.max(predict), cmap=plt.cm.get_cmap(color_pack2))

#     ax = axes[2]
#     im = ax.imshow(predict - org_data, vmin=-1, vmax=1, cmap=plt.cm.get_cmap(color_pack))
     
# fig.colorbar(im, ax=axes.ravel().tolist())
#     cax,kw = mpl.colorbar.make_axes([ax for ax in axes.flat])
cax,kw = mpl.colorbar.make_axes([axes[0]])
cax2,kw2 = mpl.colorbar.make_axes([axes[1]])
cba = plt.colorbar(im, cax=cax, **kw)
cbb = plt.colorbar(im2, cax=cax2, **kw2)

plt.savefig(path + 'experiment' + str(numOfExperiment) + '_expr_org_vs_predict.png')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-5adc7e192af5> in <module>()
# ----> 1 autoencoder = load_model('/data/multimodal/dicty/experiment_' + str(numOfExperiment) +'_cnn_expr.h5')
#       2
#       3 predict = autoencoder.predict(d.reshape(1, row, col, 1))
#       4 print(predict.shape)
#       5 print(data.shape)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/keras/engine/saving.py in load_model(filepath, custom_objects, compile)
#     216   opened_new_file = not isinstance(filepath, h5py.File)
#     217   if opened_new_file:
# --> 218     f = h5py.File(filepath, mode='r')
#     219   else:
#     220     f = filepath
#
# /usr/local/lib/python3.5/dist-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, **kwds)
#     310             with phil:
# ...

# %%
def data_generator(filenames, org_data, batch_size=1):
    # n_pack => 100 samples of matrix
    # n_pack = batch_size
    files = []              # different files
    num_packs = []          # subpacked inside of file
    for filename in filenames:
        f = np.load(filename)
        files.append(f)
        num_packs.append(f.files)
    
    counter = 0
    while True:
        x = []
        y = []
        for i in range(len(files)):
            for j in range(batch_size):
                rand_num = np.random.randint(len(num_packs[i]))
                f = files[i]
                pack = num_packs[i]
                data = f[pack[rand_num]] 
    #             new_data = top_N_rows(data)
    #             x.append(new_data)

                x.append(f[pack[rand_num]])
                y.append(org_data)
            
        x = np.asarray(x)
        y = np.asarray(y)
        
        x = x[:, 0, :, :, :]
        y = y[:, 0, :, :, :]
        
        yield ([x], [y])
        
        if counter >= batch_size:
            counter = 0

d = []
file = 'ppi'

for data in list_data:
    if data.shape[1] == 1024:
        d = data
        
row, col = d.shape
input_img = Input(shape=(row, col, 1))  # adapt this if using `channels_first` image data format
x = Conv2D(128, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2, 2), padding='same')(x)

ae = Flatten()(encoded)
ae = Dense(1024, activation='relu')(ae)
ae = Dense(512, activation='relu')(ae)
ae = Dense(256, activation='relu')(ae)
ae = Dense(128, activation='relu')(ae)
ae = Dense(64, activation='relu')(ae)
ae = Dense(128, activation='relu')(ae)
ae = Dense(256, activation='relu')(ae)
ae = Dense(512, activation='relu')(ae)
ae = Dense(1024, activation='relu')(ae) 
ae = Reshape((32, 32, 1))(ae)


# at this point the representation is (4, 4, 8) i.e. 128-dimensional

x = Conv2D(8, (3, 3), activation='relu', padding='same')(ae)
x = UpSampling2D((2, 2))(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = Model(input_img, decoded)
sgd = SGD(lr=0.001, decay=1e-6)
# autoencoder.compile(optimizer=sgd, loss='mse')
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')
autoencoder.summary() 
folder = '/data/samples/cnn/dicty/'
autoencoder.fit_generator(
    data_generator([folder+file+'.npz'], d.reshape(1, row, col, 1), 16), 
    steps_per_epoch=100, 
    epochs=100
)

autoencoder.save('/data/multimodal/dicty/experiment_'+ str(numOfExperiment) + '_cnn_' + file +'.h5')

predict = autoencoder.predict(d.reshape(1, row, col, 1))
print(predict.shape)
print(data.shape)
mse = mean_squared_error(d, predict.reshape(row, col))
print('MSE: ' + str(mse))

import matplotlib.pyplot as plt
import matplotlib as mpl

path = '/mag/Experiments/Results/'+ str(numOfExperiment) + '/dicty/'

# color_pack = 'Blues'
# color_pack = 'jet'
color_pack = 'viridis'
color_pack2 = 'RdBu'
# color_pack = 'binary'
# color_pack = 'PuOr'
# color_pack = 'rainbow'

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(25, 6))
org_data = d
predict = predict.reshape((row, col))

print(np.min(predict))
print(np.max(predict))


ax = axes[0]
im = ax.imshow(org_data, vmin=0, vmax=1, cmap=plt.cm.get_cmap(color_pack))

ax = axes[1]
im2 = ax.imshow(predict, vmin=np.min(predict), vmax=np.max(predict), cmap=plt.cm.get_cmap(color_pack2))

#     ax = axes[2]
#     im = ax.imshow(predict - org_data, vmin=-1, vmax=1, cmap=plt.cm.get_cmap(color_pack))

# fig.colorbar(im, ax=axes.ravel().tolist())
#     cax,kw = mpl.colorbar.make_axes([ax for ax in axes.flat])
cax,kw = mpl.colorbar.make_axes([axes[0]])
cax2,kw2 = mpl.colorbar.make_axes([axes[1]])
cba = plt.colorbar(im, cax=cax, **kw)
cbb = plt.colorbar(im2, cax=cax2, **kw2)

plt.savefig(path + 'experiment' + str(numOfExperiment) + '_' + file + '_org_vs_predict.png')

plt.show()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 1024, 1024, 1)     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 1024, 1024, 128)   1280
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 512, 512, 128)     0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 512, 512, 64)      73792
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 256, 256, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 256, 256, 32)      18464
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 128, 128, 32)      0
# ...

# %%
autoencoder = load_model('/data/multimodal/dicty/experiment_14_cnn_ppi.h5')

predict = autoencoder.predict(d.reshape(1, row, col, 1))
print(predict.shape)
print(data.shape)
mse = mean_squared_error(d, predict.reshape(row, col))
print('MSE: ' + str(mse))

import matplotlib.pyplot as plt
import matplotlib as mpl

path = '/mag/Experiments/Results/'+ str(numOfExperiment) + '/dicty/'

# color_pack = 'Blues'
# color_pack = 'jet'
color_pack = 'viridis'
color_pack2 = 'RdBu'
# color_pack = 'binary'
# color_pack = 'PuOr'
# color_pack = 'rainbow'

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(25, 6))
org_data = d
predict = predict.reshape((row, col))

print(np.min(predict))
print(np.max(predict))


ax = axes[0]
im = ax.imshow(org_data, vmin=0, vmax=1, cmap=plt.cm.get_cmap(color_pack))

ax = axes[1]
im2 = ax.imshow(predict, vmin=np.min(predict), vmax=np.max(predict), cmap=plt.cm.get_cmap(color_pack2))

#     ax = axes[2]
#     im = ax.imshow(predict - org_data, vmin=-1, vmax=1, cmap=plt.cm.get_cmap(color_pack))

# fig.colorbar(im, ax=axes.ravel().tolist())
#     cax,kw = mpl.colorbar.make_axes([ax for ax in axes.flat])
cax,kw = mpl.colorbar.make_axes([axes[0]])
cax2,kw2 = mpl.colorbar.make_axes([axes[1]])
cba = plt.colorbar(im, cax=cax, **kw)
cbb = plt.colorbar(im2, cax=cax2, **kw2)

plt.savefig(path + 'experiment' + str(numOfExperiment) + '_' + file + '_org_vs_predict.png')

plt.show()
# Out:
# (1, 1024, 1024, 1)
# (1024, 1024)
# MSE: 0.02139301278435536
# 0.0021243647
# 0.416103

# %%
def data_generator(filenames, n_pack, batch_size=1):
    # n_pack => 100 samples of matrix
    # n_pack = batch_size
    files = []              # different files
    num_packs = []          # subpacked inside of file
    for filename in filenames:
        f = np.load(filename)
        files.append(f)
        num_packs.append(f.files)
    
    counter = 0
    while True:
        x = []
        for i in range(len(files)):
            for j in range(batch_size):
                rand_num = np.random.randint(len(num_packs[i]))
                f = files[i]
                pack = num_packs[i]
                data = f[pack[rand_num]] 
    #             new_data = top_N_rows(data)
    #             x.append(new_data)

                x.append(f[pack[rand_num]])
            
        x = np.asarray(x)
        x = x[:, 0, :, :, :]
        yield ([x], [x])
        
        if counter >= n_pack:
            counter = 0


input_img = Input(shape=(new_row, new_col, 1))  # adapt this if using `channels_first` image data format

x = Conv2D(128, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2, 2), padding='same')(x)


encoder = Flatten()(encoded)
encoder = Dense(1024, activation='relu')(encoder)
encoder = Dense(512, activation='relu')(encoder)
encoder = Dense(256, activation='relu')(encoder)
encoder = Dense(128, activation='relu')(encoder)
encoder = Dense(64, activation='relu')(encoder)
encoder = Dense(128, activation='relu')(encoder)
encoder = Dense(256, activation='relu')(encoder)
encoder = Dense(512, activation='relu')(encoder)
encoder = Dense(1024, activation='relu')(encoder)
encoder = Reshape((128, 8, 1))(encoder)

# at this point the representation is (4, 4, 8) i.e. 128-dimensional

x = Conv2D(16, (3, 3), activation='relu', padding='same')(encoder)
x = UpSampling2D((2, 2))(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = Model(input_img, decoded)
sgd = SGD(lr=0.001, decay=1e-6)
autoencoder.compile(optimizer=sgd, loss='mse')
autoencoder.summary() 
folder = '/data/samples/cnn/dicty/ann/'
autoencoder.fit_generator(
    data_generator([folder+'ann.npz'], 1, 16), 
    steps_per_epoch=100, 
    epochs=10
)

autoencoder.save('/data/multimodal/dicty/experiment_14_2.h5')

# predict = autoencoder.predict(data.reshape(1, 2048, 128, 1))
# print(predict.shape)
# print(data.shape)
# mse = mean_squared_error(data, predict.reshape(2048, 128))
# print('MSE: ' + str(mse))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_5 (InputLayer)         (None, 2048, 128, 1)      0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 2048, 128, 128)    1280
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 1024, 64, 128)     0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 1024, 64, 64)      73792
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 512, 32, 64)       0
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 512, 32, 32)       18464
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 256, 16, 32)       0
# ...
