# %%
# !python examples/datafusion/movielens_completion.py
# Out:
# ...
# Fusion of user ratings data, movie genres and data about movie actors
# ...
#
# This example demonstrates matrix completion on user-movie preference
# data.
#
# DISCLAIMER: Results can be improved if ideas from collaborative
# filtering (regularization, user bias, item bias, etc.) are applied.
#
# User ratings: (706, 1000)
# Movie genres: (1000, 20)
# Actors played: (1000, 1000)
# Ranks:
# User: 35
# Movie: 50
# Genre: 5
# Actor: 50
# RMSE(mean rating): 0.23856379399827057
# RMSE(mean user): 0.21979482248598303
# RMSE(mean movie): 0.2165719552661239
# RMSE(ratings; out-of-sample dfmf): 0.20428483750560694
# RMSE(ratings; out-of-sample dfmf): 0.2042166554079626
# RMSE(ratings; out-of-sample dfmc): 0.21682420453737783
# RMSE(ratings; out-of-sample dfmc): 0.21656845117163886
# RMSE(in-sample dfmc): 0.04266335070009617
# RMSE(pca): 0.3598461677937439
# RMSE(nmf): 0.6196991498533774

# %%
# Out:
# =top - 19:43:22 up 209 days, 13:01,  0 users,  load average: 1.49, 1.11, 0.90
# Tasks:   9 total,   2 running,   7 sleeping,   0 stopped,   0 zombie
# %Cpu(s):  3.1 us,  9.6 sy,  0.0 ni, 87.2 id,  0.0 wa,  0.0 hi,  0.1 si,  0.0 st
# KiB Mem : 61848540 total, 48020680 free,  2473784 used, 11354076 buff/cache
# KiB Swap:  8388604 total,  6131228 free,  2257376 used. 58706908 avail Mem
#
#   PID USER      PR  NI    VIRT    RES    SHR S  %CPU %MEM     TIME+ COMMAND
#    95 root      20   0  872620 396804  26352 R 100.0  0.6   0:42.51 python
#    25 root      20   0  609736  46824  12572 S   6.2  0.1   0:09.80 python3
#     1 root      20   0   18032   2712   2496 S   0.0  0.0   0:00.07 run_jupyte+
#     8 root      20   0 2169968 217648 100444 S   0.0  0.4   0:07.75 tensorboard
#     9 root      20   0  332556  58296  15596 S   0.0  0.1   0:06.15 jupyter-no+
#    60 root      20   0   18244   3260   2780 S   0.0  0.0   0:00.20 bash
# ...
